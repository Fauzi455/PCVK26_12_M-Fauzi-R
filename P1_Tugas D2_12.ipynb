# %% [markdown]
# <a href="https://colab.research.google.com/github/Fauzi455/PCVK26_12_M-Fauzi-R/blob/main/P1_Tugas%20D2_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Langkah 1

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# Langkah 2

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://awsimages.detik.net.id/community/media/visual/2024/11/13/kucing-kecil_169.jpeg?w=700&q=90"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=700x198>

# %% [markdown]
# Langkah 3

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
#
# Out:
# resolusi image: tinggi x lebar =  198  x  350
# <PIL.Image.Image image mode=RGB size=350x198>

# %% [markdown]
# Langkah 4

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range(lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
#
# Out:
# <PIL.Image.Image image mode=RGB size=700x198>

# %% [markdown]
# #Pertanyaan
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
#
#     Jawab : Karena di google colab tidak perlu melakukan instalasi library kode program yang akan digunakan dan cukup melakukan dengan cara import library saja
#
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
#
#     Jawab : Library tersebut fungsinya untuk visualisasi data pada Google Colab dan digunakan untuk menampilkan gambar ke layar
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut : *image = cv.resive(image, (0,0), fx=0.5, fy=0.5)*
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
#
#     Jawab : Kode tersebut digunakan untuk mengubah ukuran gambar menjadi 50% atau 1/2 lebih kecil dari ukuran aslinya dan jika tidak dilakukan maka gambar akan tetap berada di ukuran semula
# 4. Perhatikan potongan kode progam berikut :*for y in range (lebar) : image_3[int((tinggi)/2),y] = [255,255,255]*
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
#     Jawab : Kode tersebut tersebut menampilkan warna putih dalam model warna RGB
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
#     Jawab : Piksel adalah titik terkecil penyusun sebuah gambar digital. Sedangkan resolus adalah jumlah total piksel yang menyusun gambar tersebut.
#     Jika resolusi tinggi berarti gambar tersusun dari jumlah piksel yang sangat banyak dan rapat. Sedangkan jika resolusi rendah berarti gambar tersusun dari jumlah piksel yang sedikit.

# %%
#TUGAS PRAKTIKUM D2

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis vertikal ditengah image
for x in range(tinggi):
  image_3[x, int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
#
# Out:
# <PIL.Image.Image image mode=RGB size=700x198>

# %%
# Pastikan variabel 'image' sudah terdefinisi sebelumnya

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Ambil dimensi gambar
tinggi, lebar = image_3.shape[:2]

# Dari kiri-atas ke kanan-bawah
cv.line(image_3, (0, 0), (lebar, tinggi), (255, 255, 255), 1)

# Dari kiri-bawah ke kanan-atas
cv.line(image_3, (0, tinggi), (lebar, 0), (255, 255, 255), 1)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=700x198>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal ditengah image dengan panjang tertentu
tengah = int(lebar / 2)

for x in range(tengah - panjang, tengah + panjang):
  image_3[int(tinggi / 2), x] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=700x198>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Ambil tinggi dan lebar
tinggi, lebar = image_3.shape[:2]

# Potong bagian tinggi tengah gambar dan potongan bagian lebar tengah gambar lalu ubah jadi putih
image_3[int(tinggi/3):int(2*tinggi/3), int(lebar/4):int(2*lebar/4)] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=700x198>
